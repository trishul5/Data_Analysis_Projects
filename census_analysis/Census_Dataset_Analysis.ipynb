# %%
# Import necessary libraries
import pandas as pd

# %%
# Following this video: https://www.youtube.com/watch?v=e1zKFSrKeLs&list=PLy3lFw0OTlutzXFVwttrtaRGEEyLEdnpy&index=6

# %%
# Read in dataset and assign it to a variable called census
dataset_path = "/Users/trishulsathiyamoorthy/Desktop/data_analysis/census_analysis/indian_census.csv"
census = pd.read_csv(dataset_path)
census
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
census.head(n=10)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
# 5              6  JAMMU AND KASHMIR       Rajouri      642415  345351  297064
# 6              7  JAMMU AND KASHMIR        Kathua      616435  326109  290326
# 7              8  JAMMU AND KASHMIR      Baramula     1008039  534733  473306
# 8              9  JAMMU AND KASHMIR     Bandipore      392232  207680  184552
# 9             10  JAMMU AND KASHMIR      Srinagar     1236829  651124  585705
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# ...

# %%
census.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
rows, columns = census.shape
print(rows)
print(columns)
# Out:
# 640
# 25

# %%
census.index
# Out:
# RangeIndex(start=0, stop=640, step=1)

# %%
census.dtypes
# Out:
# District_code            int64
# State_name              object
# District_name           object
# Population               int64
# Male                     int64
# Female                   int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %%
census
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
# Resetting index of dataset to the district code
census.set_index("District_code", inplace=True)

# %%
census
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %%
census[census["District_name"].isin(["New Delhi", "Lucknow", "Jaipur"])]
# Out:
#                   State_name District_name  Population     Male   Female  \
# District_code
# 94              NCT OF DELHI     New Delhi      142004    77942    64062
# 110                RAJASTHAN        Jaipur     6626178  3468507  3157671
# 157            UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 94               114179    59541         46940           12601
# 110             4300965  2464893       1714947          749946
# 157             3127260  1542806       1226399          316407
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 94                            121  ...        4852   2933        312    679
# 110                        744374  ...       12708  18782       1020  81079
# 157                        175578  ...       20493  23883       3877   4975
#
# ...

# %%
# Setting caption of dataset
census.style.set_caption("India Census 2011 Dataset")
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# # Find the total population for each state

# %%
census.groupby("State_name")["Population"].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# ...

# %% [markdown]
# # Find the total population based on different religion

# %%
population_by_religion = census.groupby(["Hindus", "Muslims", "Christians", "Sikhs", "Buddhists", "Jains"]).count
